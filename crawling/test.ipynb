# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import time
from bs4 import BeautifulSoup

# %%
TIME_PAUSE = 1
url = "https://serieson.naver.com/v3/movie"

# 웹드라이버 동적 할당
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=webdriver.ChromeOptions())
driver.get(url)
time.sleep(TIME_PAUSE)

# BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'lxml')

for i in range(4):
    # 선택한 요소의 첫 번째 자식을 선택하여 출력
    a_list = soup.select(f"#flicking_paging > li:nth-child(1) > a")
    a_list.c
# Out:
# Loading...HOT더빙신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~별점8.5대여11,000캐시
# Loading...HOT웡카(패키지: 자막판+더빙판+부가영상)별점8.2구매16,400캐시
# Loading...NEW소풍별점9.3대여10,000캐시
# Loading...시민덕희별점8.8구매14,900캐시

# %%
m = soup.find('div', attrs={'class':'Carousel_carousel_group__DJvD6 flicking-viewport'})
li_lists = m.find_all('li',attrs={'class':'ProductsCarouselSection_item__IUOCA Poster_large__LzP1n'})

#flicking_paging > li:nth-child(1) > a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 4
#       1 m = soup.find('div', attrs={'class':'Carousel_carousel_group__DJvD6 flicking-viewport'})
#       2 li_lists = m.find_all('li',attrs={'class':'ProductsCarouselSection_item__IUOCA Poster_large__LzP1n'})
# ----> 4 a_tag = li_lists.find_all("a")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\bs4\element.py:2428, in ResultSet.__getattr__(self, key)
#    2426 def __getattr__(self, key):
#    2427     """Raise a helpful exception to explain a common code fix."""
# -> 2428     raise AttributeError(
#    2429         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2430     )
#
# ...

# %%
m = soup.find('div', attrs={'class':'ProductsCarouselSection_carousel_area__nvWec'})
li_lists = m.find_all('li',attrs={'class':'ProductsCarouselSection_item__IUOCA Poster_large__LzP1n'})
print(len(li_lists))
# Out:
# 25

# %%
a=[]

for li in li_lists:
    a.append(li.find('a'))

print(len(a))
# Out:
# 25

# %%
a
# Out:
# [<a href="/v2/movie/617872"><div class="Thumbnail_image_wrap__KWHAU Thumbnail_type_l__frX_g"><div class="LazyImage_root__GexeS" style="width:212px;height:306px"><div class="LazyImage_imageWrap__Hc0hs LazyImage_loaded__NkzN2"><img alt="신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~" class="Thumbnail_image__TxHd0" src="https://tvstore-phinf.pstatic.net/20240312_59/1710213644239Clx2g_JPEG/3D%2BECA7B1EAB5AC%2BEAB7B9EC9EA5ED8C90_EBA994EC9DB8ED8FAC_E.jpg?type=w320_r145"/></div></div><div class="Thumbnail_bullet__Cn8X8 Thumbnail_hot__EcVjY"><span class="blind">HOT</span></div><div class="Thumbnail_bullet__Cn8X8 Thumbnail_dubbing__Clt_W"><span class="blind">더빙</span></div></div><div class="Poster_info_area__HGRo_"><span class="Title_title__s9o0D Title_large__F5jG2">신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~</span><div class="Poster_star_area___V8E2"><span class="Rating_ico_star__fW3FK Rating_large__SZHML"><span class="blind">별점</span>8.5</span></div><div class="Poster_price_group__Xremx"><div class="Price_p
# ...

# %%
img1 = img

# %%
# Out:
# [<img alt="신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~" class="Thumbnail_image__TxHd0" src="https://tvstore-phinf.pstatic.net/20240312_59/1710213644239Clx2g_JPEG/3D%2BECA7B1EAB5AC%2BEAB7B9EC9EA5ED8C90_EBA994EC9DB8ED8FAC_E.jpg?type=w320_r145"/>,
#  <img alt="웡카(패키지: 자막판+더빙판+부가영상)" class="Thumbnail_image__TxHd0" src="https://tvstore-phinf.pstatic.net/20240219_244/1708325233775UoPyr_JPEG/Wonka_STD_APO_V_DD_KA_TT_2160x2880_300dpi_KR.jpg?type=w320_r145"/>,
#  <img alt="소풍" class="Thumbnail_image__TxHd0" src="https://tvstore-phinf.pstatic.net/20240320_15/1710900838327an6R6_JPEG/PICNIC-MAIN-PO.jpg?type=w320_r145"/>,
#  <img alt="시민덕희" class="Thumbnail_image__TxHd0" src="https://s.pstatic.net/movie.phinf/20240124_126/1706084548964mScff_JPEG/movie_image.jpg?type=w320_r145"/>,
# ...

# %%
film_title =[]
for i in img:
    alt1 = i['alt']
    film_title.append(alt1)
print(film_title[2])
print(len(film_title))
# Out:
# 소풍
# 25

# %% [markdown]
# # 영화 테이블 df만들기

# %%
import numpy as np
import pandas as pd
movie = pd.DataFrame(columns=['title','director','filmDesc','runtime','releaseDate','ratings','avgGrade'])

movie
# Out:
# Empty DataFrame
# Columns: [title, director, filmDesc, runtime, releaseDate, ratings, avgGrade]
# Index: []

# %%
for i,t in enumerate(film_title):
    movie.at[i,'title'] = t

# %%
display(movie)
# Out:
#                                    title director filmDesc runtime  \
# 0   신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~      NaN      NaN     NaN
# 1                  웡카(패키지: 자막판+더빙판+부가영상)      NaN      NaN     NaN
# 2                                     소풍      NaN      NaN     NaN
# 3                                   시민덕희      NaN      NaN     NaN
# 4                                    아가일      NaN      NaN     NaN
# 5                                바튼 아카데미      NaN      NaN     NaN
# 6                                     괴물      NaN      NaN     NaN
# 7                                     화녀      NaN      NaN     NaN
# 8                                  쿵푸팬더3      NaN      NaN     NaN
# 9                                  서울의 봄      NaN      NaN     NaN
# 10                            사운드 오브 프리덤      NaN      NaN     NaN
# 11                                 도그데이즈      NaN      NaN     NaN
# 12                                 오펜하이머      NaN      NaN     NaN
# ...

# %% [markdown]
# ## 제목으로 사진 이름 저장하기

# %%
m = soup.find('div', attrs={'class':'Carousel_carousel_group__DJvD6 flicking-viewport'})
li_lists = m.find_all('li',attrs={'class':'ProductsCarouselSection_item__IUOCA Poster_large__LzP1n'})
print(len(li_lists))

# %%
img[0]['src']
# Out:
# 'https://tvstore-phinf.pstatic.net/20240312_59/1710213644239Clx2g_JPEG/3D%2BECA7B1EAB5AC%2BEAB7B9EC9EA5ED8C90_EBA994EC9DB8ED8FAC_E.jpg?type=w320_r145'

# %%
img_list =[]
for s in img:
    print(s)
# Out:
# <img alt="신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~" class="Thumbnail_image__TxHd0" src="https://tvstore-phinf.pstatic.net/20240312_59/1710213644239Clx2g_JPEG/3D%2BECA7B1EAB5AC%2BEAB7B9EC9EA5ED8C90_EBA994EC9DB8ED8FAC_E.jpg?type=w320_r145"/>
# <img alt="웡카(패키지: 자막판+더빙판+부가영상)" class="Thumbnail_image__TxHd0" src="https://tvstore-phinf.pstatic.net/20240219_244/1708325233775UoPyr_JPEG/Wonka_STD_APO_V_DD_KA_TT_2160x2880_300dpi_KR.jpg?type=w320_r145"/>
# <img alt="소풍" class="Thumbnail_image__TxHd0" src="https://tvstore-phinf.pstatic.net/20240320_15/1710900838327an6R6_JPEG/PICNIC-MAIN-PO.jpg?type=w320_r145"/>
# <img alt="시민덕희" class="Thumbnail_image__TxHd0" src="https://s.pstatic.net/movie.phinf/20240124_126/1706084548964mScff_JPEG/movie_image.jpg?type=w320_r145"/>
# <img alt="아가일" class="Thumbnail_image__TxHd0" src="https://tvstore-phinf.pstatic.net/20240307_13/1709792021345qNKQ4_JPEG/Argylle_2000x3000_kr_kor_keyart_full_digital_artwork_RGB_V1_sprk_LSR_Alt_SafeArt.jpg?type=w320_r145"/>
# ...

# %% [markdown]
# # oracleDB 연동

# %%
# !pip install oracledb
import oracledb
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.6 MB 2.4 MB/s eta 0:00:01
#    -------- ------------------------------- 0.3/1.6 MB 3.0 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.6 MB 3.5 MB/s eta 0:00:01
#    ------------------ --------------------- 0.7/1.6 MB 3.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.9/1.6 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 3.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.4/1.6 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.6 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
# ...

# %%
conn = oracledb.connect(user="hr", password="hr", dsn="localhost:1521/xe")
cursor = conn.cursor()

# %%
cursor.execute("select * from employees")
out_data = cursor.fetchall()
for record in out_data:
    print(record)
# Out:
# (100, 'Steven', 'King', 'SKING', '515.123.4567', datetime.datetime(2003, 6, 17, 0, 0), 'AD_PRES', 24000.0, None, None, 90)
# (101, 'Neena', 'Kochhar', 'NKOCHHAR', '515.123.4568', datetime.datetime(2005, 9, 21, 0, 0), 'AD_VP', 17000.0, None, 100, 90)
# (102, 'Lex', 'De Haan', 'LDEHAAN', '515.123.4569', datetime.datetime(2001, 1, 13, 0, 0), 'AD_VP', 17000.0, None, 100, 90)
# (103, 'Alexander', 'Hunold', 'AHUNOLD', '590.423.4567', datetime.datetime(2006, 1, 3, 0, 0), 'IT_PROG', 9000.0, None, 102, 60)
# (104, 'Bruce', 'Ernst', 'BERNST', '590.423.4568', datetime.datetime(2007, 5, 21, 0, 0), 'IT_PROG', 6000.0, None, 103, 60)
# (105, 'David', 'Austin', 'DAUSTIN', '590.423.4569', datetime.datetime(2005, 6, 25, 0, 0), 'IT_PROG', 4800.0, None, 103, 60)
# (106, 'Valli', 'Pataballa', 'VPATABAL', '590.423.4560', datetime.datetime(2006, 2, 5, 0, 0), 'IT_PROG', 4800.0, None, 103, 60)
# ...
